# %% [markdown]
# **Notebook to create the Spanish and German Wikipedia datasets.**
#
# This is done by combining descriptions per species and source to get one combined description for a species that might contain several WIKI categories. The descriptions are then merged with information on species traits from the Global Inventory of Floras and Traits (GIFT).

# %% [markdown]
# # Libraries & Functions

# %%
'''Math & Data Libraries'''
import numpy as np
import pandas as pd

# %%
''' Miscellaneous Libraries'''
from tqdm import tqdm

# %% [markdown]
# # Input Description Data

# %% [markdown]
# ## Spanish Wikipedia - WIKI_ES Dataset

# %%
df_WIKI_ES = pd.read_excel("..//Datasets//Preprocessed Databases//WIKI_preprocessed_descriptions_ESP.xlsx")

# %%
df_WIKI_ES
# Out:
#                 WIKI_id                                        description  \
# 0               Summary  Salsola oppositifolia o salao borde es una pla...
# 1              HÃ¡bitat  Es propia de zonas costeras. Tolerante a la sa...
# 2          DescripciÃ³n  Se trata de un arbusto de hasta 2 m de altura,...
# 3            TaxonomÃ­a  Salsola oppositifolia fue descrita por RenÃ© L...
# 4       Nombres comunes  Castellano: barrilla, barrilla zagua, boja bar...
# ...                 ...                                                ...
# 24526           Summary  Dierama pulcherrimum, es una especie de planta...
# 24527      DescripciÃ³n  Se caracteriza por sus flores laxas de color g...
# 24528        TaxonomÃ­a  Dierama pulcherrimum fue descrita por (Hook.f....
# 24529       Referencias                                                NaN
# 24530  Enlaces externos   Wikispecies tiene un artÃ­culo sobre Dierama ...
#
#        source                   name Date Retrieved          Binomial Name  \
# 0           1  Salsola oppositifolia     2023-05-09  Salsola oppositifolia
# 1           2  Salsola oppositifolia     2023-05-09  Salsola oppositifolia
# 2           3  Salsola oppositifolia     2023-05-09  Salsola oppositifolia
# 3           4  Salsola oppositifolia     2023-05-09  Salsola oppositifolia
# 4           5  Salsola oppositifolia     2023-05-09  Salsola oppositifolia
# ...       ...                    ...            ...                    ...
# 24526   24527   Dierama pulcherrimum     2023-05-09   Dierama pulcherrimum
# 24527   24528   Dierama pulcherrimum     2023-05-09   Dierama pulcherrimum
# 24528   24529   Dierama pulcherrimum     2023-05-09   Dierama pulcherrimum
# 24529   24530   Dierama pulcherrimum     2023-05-09   Dierama pulcherrimum
# 24530   24531   Dierama pulcherrimum     2023-05-09   Dierama pulcherrimum
#
#                                       prep_description_1  \
# 0      Salsola oppositifolia o salao borde es una pla...
# 1      Es propia de zonas costeras. Tolerante a la sa...
# 2      Se trata de un arbusto de hasta 2 m de altura,...
# 3      Salsola oppositifolia fue descrita por RenA(c)...
# 4      Castellano: barrilla, barrilla zagua, boja bar...
# ...                                                  ...
# 24526  Dierama pulcherrimum, es una especie de planta...
# 24527  Se caracteriza por sus flores laxas de color g...
# 24528  Dierama pulcherrimum fue descrita por (Hook.f....
# 24529                                                NaN
# 24530   Wikispecies tiene un artAculo sobre Dierama p...
#
#                                           QA_description  \
# 0      salsola oppositifolia o salao borde es una pla...
# 1      es propia de zonas costeras . tolerante a la s...
# 2      se trata de un arbusto de hasta 2 m de altura ...
# 3      salsola oppositifolia fue descrita por rena ( ...
# 4      castellano : barrilla , barrilla zagua , boja ...
# ...                                                  ...
# 24526  dierama pulcherrimum , es una especie de plant...
# 24527  se caracteriza por sus flores laxas de color g...
# 24528  dierama pulcherrimum fue descrita por ( hook.f...
# 24529                                                NaN
# 24530  wikispecies tiene un artaculo sobre dierama pu...
#
#                                         BERT_description  \
# 0      salsola oppositifolia salao borde es una plant...
# 1      es propia de zonas costeras tolerante la salin...
# 2      se trata de un arbusto de hasta de altura de c...
# 3      salsola oppositifolia fue descrita por renac l...
# 4      castellano barrilla barrilla zagua boja barril...
# ...                                                  ...
# 24526  dierama pulcherrimum es una especie de planta ...
# 24527  se caracteriza por sus flores laxas de color g...
# 24528  dierama pulcherrimum fue descrita por hookf ba...
# 24529                                                NaN
# 24530  wikispecies tiene un artaculo sobre dierama pu...
#
#                                          BOW_description
# 0      salsola oppositifolia salao borde es una plant...
# 1      es propia de zonas costeras tolerante la salin...
# 2      se trata de un arbusto de hasta de altura de c...
# 3      salsola oppositifolia fue descrita por renac l...
# 4      castellano barrilla barrilla zagua boja barril...
# ...                                                  ...
# 24526  dierama pulcherrimum es una especie de planta ...
# 24527  se caracteriza por sus flores laxas de color g...
# 24528  dierama pulcherrimum fue descrita por hookf ba...
# 24529                                                NaN
# 24530  wikispecies tiene un artaculo sobre dierama pu...
#
# [24531 rows x 10 columns]

# %% [markdown]
# ## German Wikipedia - WIKI_DE Dataset

# %%
df_WIKI_DE = pd.read_excel("..//Datasets//Preprocessed Databases//WIKI_preprocessed_descriptions_DE.xlsx")

# %%
df_WIKI_DE
# Out:
#                WIKI_id                                        description  \
# 0              Summary  Macadamia integrifolia ist eine Pflanzenart au...
# 1         Beschreibung  Macadamia integrifolia wÃ¤chst als Baum und er...
# 2          Verbreitung  Macadamia integrifolia ist in einem kleinen Ge...
# 3           Verwendung  Die Samen von Macadamia integrifolia sind essb...
# 4      Einzelnachweise                                 \n\n== Weblinks ==
# ...                ...                                                ...
# 20270     Beschreibung  Der Kaukasische Klee ist eine ausdauernde, kra...
# 20271      Verbreitung  Kaukasischer Klee ist auf GerÃ¶llfeldern, an W...
# 20272          Nutzung  Kaukasischer Klee wird vor allem in Osteuropa ...
# 20273        Literatur  Michael Zohary, David Heller: The Genus Trifol...
# 20274         Weblinks  \nEintrag der Gattung im LegumeWeb\n\n\n== Ein...
#
#        source                    name Date Retrieved           Binomial Name  \
# 0         NaN  Macadamia integrifolia     2023-08-09  Macadamia integrifolia
# 1         NaN  Macadamia integrifolia     2023-08-09  Macadamia integrifolia
# 2         NaN  Macadamia integrifolia     2023-08-09  Macadamia integrifolia
# 3         NaN  Macadamia integrifolia     2023-08-09  Macadamia integrifolia
# 4         NaN  Macadamia integrifolia     2023-08-09  Macadamia integrifolia
# ...       ...                     ...            ...                     ...
# 20270     NaN      Trifolium ambiguum     2023-08-09      Trifolium ambiguum
# 20271     NaN      Trifolium ambiguum     2023-08-09      Trifolium ambiguum
# 20272     NaN      Trifolium ambiguum     2023-08-09      Trifolium ambiguum
# 20273     NaN      Trifolium ambiguum     2023-08-09      Trifolium ambiguum
# 20274     NaN      Trifolium ambiguum     2023-08-09      Trifolium ambiguum
#
#                                       prep_description_1  \
# 0      Macadamia integrifolia ist eine Pflanzenart au...
# 1      Macadamia integrifolia wA$?chst als Baum und e...
# 2      Macadamia integrifolia ist in einem kleinen Ge...
# 3      Die Samen von Macadamia integrifolia sind essb...
# 4                                     \n\n== Weblinks ==
# ...                                                  ...
# 20270  Der Kaukasische Klee ist eine ausdauernde, kra...
# 20271  Kaukasischer Klee ist auf GerAPllfeldern, an W...
# 20272  Kaukasischer Klee wird vor allem in Osteuropa ...
# 20273  Michael Zohary, David Heller: The Genus Trifol...
# 20274  \nEintrag der Gattung im LegumeWeb\n\n\n== Ein...
#
#                                           QA_description  \
# 0      macadamia integrifolia ist eine pflanzenart au...
# 1      macadamia integrifolia wa $ ? chst als baum un...
# 2      macadamia integrifolia ist in einem kleinen ge...
# 3      die samen von macadamia integrifolia sind essb...
# 4                                                      0
# ...                                                  ...
# 20270  der kaukasische klee ist eine ausdauernde , kr...
# 20271  kaukasischer klee ist auf gerapllfeldern , an ...
# 20272  kaukasischer klee wird vor allem in osteuropa ...
# 20273  michael zohary , david heller : the genus trif...
# 20274  eintrag der gattung im legumeweb == einzelnach...
#
#                                         BERT_description  \
# 0      macadamia integrifolia ist eine pflanzenart au...
# 1      macadamia integrifolia wachst als baum und err...
# 2      macadamia integrifolia ist in einem kleinen ge...
# 3      die samen von macadamia integrifolia sind essb...
# 4                                               weblinks
# ...                                                  ...
# 20270  der kaukasische klee ist eine ausdauernde krau...
# 20271  kaukasischer klee ist auf gerapllfeldern an wa...
# 20272  kaukasischer klee wird vor allem in osteuropa ...
# 20273  michael zohary david heller the genus trifoliu...
# 20274   eintrag der gattung im legumeweb einzelnachweise
#
#                                          BOW_description
# 0      macadamia integrifolia ist eine pflanzenart au...
# 1      macadamia integrifolia wachst als baum und err...
# 2      macadamia integrifolia ist einem kleinen gebie...
# 3      die samen von macadamia integrifolia sind essb...
# 4                                               weblinks
# ...                                                  ...
# 20270  der kaukasische klee ist eine ausdauernde krau...
# 20271  kaukasischer klee ist auf gerapllfeldern waldr...
# 20272  kaukasischer klee wird vor allem osteuropa int...
# 20273  michael zohary david heller genus trifolium is...
# 20274   eintrag der gattung im legumeweb einzelnachweise
#
# [20275 rows x 10 columns]

# %% [markdown]
# ## Statistics

# %%
print("Number of Unique Species: {}".format(df_WIKI_ES["name"].nunique()))
print("Number of Unique Description Types: {}".format(df_WIKI_ES["WIKI_id"].nunique()))
# Out:
# Number of Unique Species: 4196
# Number of Unique Description Types: 1076

# %%
df_WIKI_ES["WIKI_id"].value_counts().describe()
# Out:
# count    1076.000000
# mean       22.798327
# std       234.497474
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max      4196.000000
# Name: count, dtype: float64

# %%
print("Number of Unique Species: {}".format(df_WIKI_DE["name"].nunique()))
print("Number of Unique Description Types: {}".format(df_WIKI_DE["WIKI_id"].nunique()))
# Out:
# Number of Unique Species: 2419
# Number of Unique Description Types: 1361

# %%
df_WIKI_DE["WIKI_id"].value_counts().describe()
# Out:
# count    1361.000000
# mean       14.897134
# std       116.076780
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max      2420.000000
# Name: count, dtype: float64

# %% [markdown]
# # Combine Descriptions on Species

# %%
def combine_descriptions(df, df_name):
    df_new = pd.DataFrame()
    
    src_variable = "authors" if df_name=="POWO" else "Binomial Name" 

    # Adding variables for the categories and their count
    df_tmp = df.groupby(["name", src_variable])[f'{df_name}_id'].apply(';'.join).reset_index()
    df_new = df_new.assign(name = df_tmp["name"])
    df_new = df_new.assign(binname = df_tmp[src_variable])
    df_new[f'{df_name}_ids'] = df_tmp[f'{df_name}_id']
    df_new[f'{df_name}_id_N'] = [len(x.split(";")) for x in df_tmp[f'{df_name}_id']]

    # Combining the original description
    description = df["description"].apply(str)
    df = df.assign(description_str=description)
    df_tmp = df.groupby(["name", src_variable])['description_str'].apply(' ; '.join).reset_index()
    df_new = df_new.assign(description=df_tmp["description_str"])

    # Combining the QA description
    QA_description = df["QA_description"].apply(str)
    df = df.assign(QA_description_str=QA_description)
    df_tmp = df.groupby(["name", src_variable])['QA_description_str'].apply(' ; '.join).reset_index()
    df_new = df_new.assign(QA_description=df_tmp["QA_description_str"])
    
    # Combining the BERT description
    BERT_description = df["BERT_description"].apply(str)
    df = df.assign(BERT_description_str=BERT_description)
    df_tmp = df.groupby(["name", src_variable])['BERT_description_str'].apply(' '.join).reset_index()
    df_new = df_new.assign(BERT_description=df_tmp["BERT_description_str"])
    
    # Combining the BOW description
    BOW_description = df["BOW_description"].apply(str)
    df = df.assign(BOW_description_str=BOW_description)
    df_tmp = df.groupby(["name", src_variable])['BOW_description_str'].apply(' '.join).reset_index()
    df_new = df_new.assign(BOW_description=df_tmp["BOW_description_str"])

    return df_new

# %%
df_WIKI_ES_combined = combine_descriptions(df_WIKI_ES, "WIKI")
df_WIKI_DE_combined = combine_descriptions(df_WIKI_DE, "WIKI")

# %% [markdown]
# ### Description Word Count & Character Count Analysis

# %%
character_count_description = df_WIKI_ES_combined["BERT_description"].apply(lambda x: len(x))
df_WIKI_ES_combined = df_WIKI_ES_combined.assign(description_character_count=character_count_description)

word_count_description = df_WIKI_ES_combined["BERT_description"].apply(lambda x: len(x.split()))
df_WIKI_ES_combined = df_WIKI_ES_combined.assign(description_word_count=word_count_description)

character_count_description = df_WIKI_DE_combined["BERT_description"].apply(lambda x: len(x))
df_WIKI_DE_combined = df_WIKI_DE_combined.assign(description_character_count=character_count_description)

word_count_description = df_WIKI_DE_combined["BERT_description"].apply(lambda x: len(x.split()))
df_WIKI_DE_combined = df_WIKI_DE_combined.assign(description_word_count=word_count_description)

# %% [markdown]
# # Input Label Data

# %% [markdown]
# ## Global Inventory of Floras and Traits - GIFT Dataset

# %% [markdown]
# ### GIFT Trait Data

# %%
df_GIFT_traits = pd.read_csv("..//Datasets//Initial Databases//GIFT_traits.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\3784903675.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_GIFT_traits = pd.read_csv("..//Datasets//Initial Databases//GIFT_traits.csv")

# %%
df_GIFT_traits
# Out:
#          work_ID trait_ID   trait_value  agreement   references  \
# 0              1    1.1.1     non-woody        1.0        10465
# 1              1    1.2.1          herb        1.0        10465
# 2              1    1.2.2          herb        1.0        10465
# 3              1    1.6.1          0.05        NaN        10342
# 4              1    1.6.1          0.05        NaN  10254,10342
# ...          ...      ...           ...        ...          ...
# 5793217   437924    3.3.2  anemochorous        1.0        10652
# 5793218   437962    3.3.1  anemochorous        1.0        10652
# 5793219   437962    3.3.2  anemochorous        1.0        10652
# 5793220   437984    3.3.1    zoochorous        1.0        10652
# 5793221   437984    3.3.2    zoochorous        1.0        10652
#
#          bias_by_reference  bias_by_derivation  restricted
# 0                        0                   1           1
# 1                        0                   1           1
# 2                        0                   1           1
# 3                        0                   0           0
# 4                        0                   0           1
# ...                    ...                 ...         ...
# 5793217                  0                   0           1
# 5793218                  0                   0           1
# 5793219                  0                   0           1
# 5793220                  0                   0           1
# 5793221                  0                   0           1
#
# [5793222 rows x 8 columns]

# %%
df_GIFT_traits = df_GIFT_traits[df_GIFT_traits["restricted"]==1].drop(["restricted"], axis=1)

# %%
df_GIFT_traits
# Out:
#          work_ID trait_ID   trait_value  agreement   references  \
# 0              1    1.1.1     non-woody        1.0        10465
# 1              1    1.2.1          herb        1.0        10465
# 2              1    1.2.2          herb        1.0        10465
# 4              1    1.6.1          0.05        NaN  10254,10342
# 6              1    1.6.2           0.2        NaN  10254,10342
# ...          ...      ...           ...        ...          ...
# 5793217   437924    3.3.2  anemochorous        1.0        10652
# 5793218   437962    3.3.1  anemochorous        1.0        10652
# 5793219   437962    3.3.2  anemochorous        1.0        10652
# 5793220   437984    3.3.1    zoochorous        1.0        10652
# 5793221   437984    3.3.2    zoochorous        1.0        10652
#
#          bias_by_reference  bias_by_derivation
# 0                        0                   1
# 1                        0                   1
# 2                        0                   1
# 4                        0                   0
# 6                        0                   0
# ...                    ...                 ...
# 5793217                  0                   0
# 5793218                  0                   0
# 5793219                  0                   0
# 5793220                  0                   0
# 5793221                  0                   0
#
# [3004940 rows x 7 columns]

# %% [markdown]
# #### Filter Traits

# %%
trait_names_cat = ["Growth_form_1", "Epiphyte_1", "Climber_1", "Lifecycle_1", "Life_form_1"]
traits_cat = ["1.2.1", "1.3.1", "1.4.1", "2.1.1", "2.3.1"]

# %%
trait_names_num = ["Plant_height_max", "Leaf_length_max", "Leaf_width_max"]
traits_num = ["1.6.2", "4.6.2", "4.7.2"]

# %%
trait_dict = {trait_code: trait_name for trait_code, trait_name in zip(np.hstack((traits_cat, traits_num)), np.hstack((trait_names_cat, trait_names_num)))}

# %%
for trait_code, trait_name in zip(np.hstack((traits_cat, traits_num)), np.hstack((trait_names_cat, trait_names_num))):
    print("Trait: {}\nCode: {}\nCount {}".format(trait_name, trait_code, df_GIFT_traits["trait_ID"].value_counts()[trait_code]))
    print("------")
# Out:
# Trait: Growth_form_1
# Code: 1.2.1
# Count 251006
# ------
# Trait: Epiphyte_1
# Code: 1.3.1
# Count 216396
# ------
# Trait: Climber_1
# Code: 1.4.1
# Count 230761
# ------
# Trait: Lifecycle_1
# Code: 2.1.1
# Count 202302
# ------
# Trait: Life_form_1
# Code: 2.3.1
# Count 102055
# ------
# Trait: Plant_height_max
# Code: 1.6.2
# Count 78968
# ------
# Trait: Leaf_length_max
# Code: 4.6.2
# Count 20347
# ------
# Trait: Leaf_width_max
# Code: 4.7.2
# Count 17110
# ------

# %%
# Filtering Data based on selected traits - WARNING: REWRITING DATAFRAME
df_GIFT_traits = df_GIFT_traits[df_GIFT_traits["trait_ID"].apply(lambda x: x in np.hstack((traits_cat, traits_num)))]

# %%
# Drop Duplicates - WARNING: REWRITING DATAFRAME
df_GIFT_traits = df_GIFT_traits.drop_duplicates(["work_ID", "trait_ID", "trait_value", "references", "bias_by_reference", "bias_by_derivation"])

# %%
df_GIFT_traits
# Out:
#          work_ID trait_ID      trait_value  agreement   references  \
# 1              1    1.2.1             herb        1.0        10465
# 6              1    1.6.2              0.2        NaN  10254,10342
# 9              1    2.3.1  hemicryptophyte        1.0        10465
# 33             3    1.2.1             tree        1.0  10321,10598
# 35             3    2.1.1        perennial        1.0  10321,10598
# ...          ...      ...              ...        ...          ...
# 5793183   437906    1.6.2              0.3        NaN        10651
# 5793187   437906    2.1.1        perennial        1.0        10651
# 5793197   437907    1.2.1             herb        1.0        10651
# 5793201   437907    1.6.2              0.6        NaN        10651
# 5793205   437907    2.1.1        perennial        1.0        10651
#
#          bias_by_reference  bias_by_derivation
# 1                        0                   1
# 6                        0                   0
# 9                        0                   0
# 33                       1                   0
# 35                       1                   1
# ...                    ...                 ...
# 5793183                  0                   0
# 5793187                  0                   0
# 5793197                  0                   0
# 5793201                  0                   0
# 5793205                  0                   0
#
# [1118945 rows x 7 columns]

# %%
print("Number of Unique Species: {}".format(df_GIFT_traits["work_ID"].nunique()))
print("Average Number of Traits Per Species: {} (Max: {})".format(np.round(len(df_GIFT_traits)/df_GIFT_traits["work_ID"].nunique(), 2), len(trait_dict)))
# Out:
# Number of Unique Species: 288159
# Average Number of Traits Per Species: 3.88 (Max: 8)

# %% [markdown]
# ### GIFT Species Data

# %%
df_GIFT_names = pd.read_csv("..//Datasets//Initial Databases//GIFT_names_matched.csv")

# %%
df_GIFT_names
# Out:
#         orig_ID  name_ID       genus species_epithet subtaxon  \
# 0           1.0     3136  Amaranthus     interruptus      NaN
# 1           2.0     5078     Argusia        argentea      NaN
# 2           3.0    18061      Cordia      subcordata      NaN
# 3           4.0    16442      Cleome        gynandra      NaN
# 4           5.0    37713     Ipomoea       macrantha      NaN
# ...         ...      ...         ...             ...      ...
# 992258      NaN   877624         NaN             NaN      NaN
# 992259      NaN   877626         NaN             NaN      NaN
# 992260      NaN   877633         NaN             NaN      NaN
# 992261      NaN   877635         NaN             NaN      NaN
# 992262      NaN   877638         NaN             NaN      NaN
#
#                  author          family  matched  epithetscore  overallscore  \
# 0                 R.Br.   Amaranthaceae        1           1.0      1.000000
# 1          (L.f.) Heine    Boraginaceae        1           1.0      1.000000
# 2                  Lam.    Boraginaceae        1           1.0      1.000000
# 3                    L.      Cleomaceae        1           1.0      1.000000
# 4       Roem. & Schult.  Convolvulaceae        1           1.0      1.000000
# ...                 ...             ...      ...           ...           ...
# 992258              NaN     Leguminosae        1           1.0      0.648649
# 992259              NaN     Leguminosae        1           1.0      0.742857
# 992260              NaN  Caprifoliaceae        1           1.0      0.697674
# 992261              NaN     Leguminosae        1           1.0      0.666667
# 992262              NaN     Leguminosae        1           1.0      0.714286
#
#         resolved service  work_ID                 species
# 0              1     tpl     1943  Amaranthus interruptus
# 1              0     tpl     3128        Argusia argentea
# 2              1     tpl    11046       Cordia subcordata
# 3              1     tpl     9985         Cleome gynandra
# 4              1     tpl    23490        Ipomoea violacea
# ...          ...     ...      ...                     ...
# 992258         1     tpl   102406        Trifolium tumens
# 992259         1     tpl   381907     Trigonella gracilis
# 992260         0     tpl    79926     Valeriana stracheyi
# 992261         1     tpl    57728          Vicia johannis
# 992262         1     tpl    47337       Wisteria sinensis
#
# [992263 rows x 14 columns]

# %% [markdown]
# ## Combine Label Information & Convert to Wide

# %%
df_GIFT_long = df_GIFT_traits.merge(df_GIFT_names[["work_ID", "species"]], how='left', on='work_ID').drop_duplicates()

# %%
df_GIFT_long
# Out:
#          work_ID trait_ID      trait_value  agreement   references  \
# 0              1    1.2.1             herb        1.0        10465
# 11             1    1.6.2              0.2        NaN  10254,10342
# 22             1    2.3.1  hemicryptophyte        1.0        10465
# 33             3    1.2.1             tree        1.0  10321,10598
# 36             3    2.1.1        perennial        1.0  10321,10598
# ...          ...      ...              ...        ...          ...
# 3907626   437906    1.6.2              0.3        NaN        10651
# 3907627   437906    2.1.1        perennial        1.0        10651
# 3907628   437907    1.2.1             herb        1.0        10651
# 3907629   437907    1.6.2              0.6        NaN        10651
# 3907630   437907    2.1.1        perennial        1.0        10651
#
#          bias_by_reference  bias_by_derivation                species
# 0                        0                   1  Aaronsohnia pubescens
# 11                       0                   0  Aaronsohnia pubescens
# 22                       0                   0  Aaronsohnia pubescens
# 33                       1                   0       Abarema abbottii
# 36                       1                   1       Abarema abbottii
# ...                    ...                 ...                    ...
# 3907626                  0                   0      Silene ispirensis
# 3907627                  0                   0      Silene ispirensis
# 3907628                  0                   0  Antitoxicum raddeanum
# 3907629                  0                   0  Antitoxicum raddeanum
# 3907630                  0                   0  Antitoxicum raddeanum
#
# [1118945 rows x 8 columns]

# %%
def long_to_wide(df, trait_dict):
    df_new = pd.DataFrame(index=np.unique(df["work_ID"]))
    df_new["work_ID"] = np.unique(df["work_ID"])
    df_new["species"] = df.groupby("work_ID")["species"].aggregate(lambda x: ''.join(set(x)))
    
    for trait_code in trait_dict:
        df_tmp = df[df["trait_ID"]==trait_code]#.astype(str)
        df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
        df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
        df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
        
        df_new[trait_code + "_count"] = df_tmp[df_tmp["trait_value"].notna()].groupby("work_ID")["trait_value"].count()
        df_new[trait_code] = df_tmp[df_tmp["trait_value"].notna()].groupby("work_ID")["trait_value"].aggregate(lambda x: "|".join(np.unique(np.hstack(x))))
        df_new[trait_code + "_agreement"] = df_tmp[df_tmp["trait_value"].notna()].groupby("work_ID")["agreement"].aggregate(lambda x: "|".join(np.hstack(x)))
        df_new[trait_code + "_bias_by_reference"] = df_tmp[df_tmp["trait_value"].notna()].groupby("work_ID")["bias_by_reference"].aggregate(lambda x: "|".join(np.hstack(x)))
        df_new[trait_code + "_bias_by_derivation"] = df_tmp[df_tmp["trait_value"].notna()].groupby("work_ID")["bias_by_derivation"].aggregate(lambda x: "|".join(np.hstack(x)))

    return df_new

# %%
df_GIFT_wide = long_to_wide(df_GIFT_long, trait_dict)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["agreement"] = np.round(df_tmp["agreement"], 2).astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_reference"] = df_tmp["bias_by_reference"].astype(str)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_120236\792339275.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tmp["bias_by_derivation"] = df_tmp["bias_by_derivation"].astype(str)

# %%
df_GIFT_wide
# Out:
#         work_ID                  species  1.2.1_count  1.2.1 1.2.1_agreement  \
# 1             1    Aaronsohnia pubescens          1.0   herb             1.0
# 3             3         Abarema abbottii          1.0   tree             1.0
# 4             4        Abarema alexandri          1.0   tree             1.0
# 5             5     Abarema asplenifolia          1.0   tree             1.0
# 6             6           Abarema glauca          1.0   tree             1.0
# ...         ...                      ...          ...    ...             ...
# 437903   437903    Razoumowskya oxycerdi          1.0  shrub             1.0
# 437904   437904              Rosa bifera          1.0  shrub             1.0
# 437905   437905  Saussurea pulviniformis          NaN    NaN             NaN
# 437906   437906        Silene ispirensis          NaN    NaN             NaN
# 437907   437907    Antitoxicum raddeanum          1.0   herb             1.0
#
#        1.2.1_bias_by_reference 1.2.1_bias_by_derivation  1.3.1_count  \
# 1                            0                        1          NaN
# 3                            1                        0          NaN
# 4                            0                        0          NaN
# 5                            1                        0          NaN
# 6                            0                        0          1.0
# ...                        ...                      ...          ...
# 437903                       0                        0          NaN
# 437904                       0                        0          NaN
# 437905                     NaN                      NaN          NaN
# 437906                     NaN                      NaN          NaN
# 437907                       0                        0          NaN
#
#               1.3.1 1.3.1_agreement  ... 4.6.2_count 4.6.2  4.6.2_agreement  \
# 1               NaN             NaN  ...         NaN   NaN              NaN
# 3               NaN             NaN  ...         NaN   NaN              NaN
# 4               NaN             NaN  ...         NaN   NaN              NaN
# 5               NaN             NaN  ...         NaN   NaN              NaN
# 6       terrestrial             1.0  ...         NaN   NaN              NaN
# ...             ...             ...  ...         ...   ...              ...
# 437903          NaN             NaN  ...         NaN   NaN              NaN
# 437904          NaN             NaN  ...         NaN   NaN              NaN
# 437905          NaN             NaN  ...         NaN   NaN              NaN
# 437906          NaN             NaN  ...         NaN   NaN              NaN
# 437907          NaN             NaN  ...         NaN   NaN              NaN
#
#        4.6.2_bias_by_reference 4.6.2_bias_by_derivation 4.7.2_count 4.7.2  \
# 1                          NaN                      NaN         NaN   NaN
# 3                          NaN                      NaN         NaN   NaN
# 4                          NaN                      NaN         NaN   NaN
# 5                          NaN                      NaN         NaN   NaN
# 6                          NaN                      NaN         NaN   NaN
# ...                        ...                      ...         ...   ...
# 437903                     NaN                      NaN         NaN   NaN
# 437904                     NaN                      NaN         NaN   NaN
# 437905                     NaN                      NaN         NaN   NaN
# 437906                     NaN                      NaN         NaN   NaN
# 437907                     NaN                      NaN         NaN   NaN
#
#         4.7.2_agreement 4.7.2_bias_by_reference 4.7.2_bias_by_derivation
# 1                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# 5                   NaN                     NaN                      NaN
# 6                   NaN                     NaN                      NaN
# ...                 ...                     ...                      ...
# 437903              NaN                     NaN                      NaN
# 437904              NaN                     NaN                      NaN
# 437905              NaN                     NaN                      NaN
# 437906              NaN                     NaN                      NaN
# 437907              NaN                     NaN                      NaN
#
# [288159 rows x 42 columns]

# %% [markdown]
# # Combine Description & Trait Data

# %%
"""Combine the WIKI and GIFT databases regards to their species name and add the wanted traits"""
def combine_description_trait_data(df, df_GIFT):
    df_GIFT["key"] = df_GIFT["species"]
    df["key"] = df["name"]
    df = pd.merge(df, df_GIFT, how = "left", on = "key")
    df.drop("key", axis=1, inplace=True)
    return df

# %% [markdown]
# ## WIKI_GIFT

# %%
df_WIKI_GIFT_ESP = combine_description_trait_data(df_WIKI_ES_combined, df_GIFT_wide)
df_WIKI_GIFT_DE = combine_description_trait_data(df_WIKI_DE_combined, df_GIFT_wide)

# %% [markdown]
# ## Save Data

# %%
df_WIKI_GIFT_ESP.to_excel("..//Datasets//WIKI_GIFT_ESP.xlsx", index = False)
df_WIKI_GIFT_DE.to_excel("..//Datasets//WIKI_GIFT_DE.xlsx", index = False)
